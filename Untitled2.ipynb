# %% [markdown]
# <a href="https://colab.research.google.com/github/luiz675/aula/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome_aluno = 'Luiz Adriano'
print('nome do aluno: %s' %(nome_aluno))
# Out:
# nome do aluno: Luiz Adriano

# %%
nome_aluno = 'Luiz Adriano'
idade_aluno = 43
media_aluno = 8.45
print('nome do aluno é %s, ele tem %d anos e sua média e %f ' %(nome_aluno, idade_aluno, media_aluno))
# Out:
# nome do aluno é Luiz Adriano, ele tem 43 anos e sua média e 8.450000

# %%
print('nome do aluno é %s, ele tem %d anos e sua média e %.2f.' %(nome_aluno, idade_aluno, media_aluno))
# Out:
# nome do aluno é Luiz Adriano, ele tem 43 anos e sua média e 8.45.

# %%
nome_aluno = 'Luiz Adriano'
print('Nome do aluno: {}'.format(nome_aluno))
# Out:
# Nome do aluno: Luiz Adriano

# %%
nome_aluno = 'Luiz Adriano'
idade_aluno = 43
media_aluno = 8.45
print('nome do aluno é {}, ele tem {} anos e sua média é {}.' .format(nome_aluno, idade_aluno, media_aluno))
# Out:
# nome do aluno é Luiz Adriano, ele tem 43 anos e sua média é 8.45.

# %%
print('Estudar é um esforço constante, \nÉ como cultivar uma planta, \nPrecisamos de dedicação e paciência, \nPara ver o fruto amadurecer. ')
# Out:
# Estudar é um esforço constante,
# É como cultivar uma planta,
# Precisamos de dedicação e paciência,
# Para ver o fruto amadurecer.

# %%
print('Quantidade\tQuantidade\n5 amostras \tAlta\n3 amostar\tBaixa')
# Out:
# Quantidade	Quantidade
# 5 amostras 	Alta
# 3 amostar	Baixa

# %%
print('Caminho do arquivo: c:\\arquivo\\documento.csv')
# Out:
# Caminho do arquivo: c:\arquivo\documento.csv

# %%
print("Ouvi uma vez \"Os frutos do conhecimento são os mais doces e duradores de todos.\"")
# Out:
# Ouvi uma vez "Os frutos do conhecimento são os mais doces e duradores de todos."

# %%
print('Minha professora uma vez disse \'Estudar e chave do sucesso.\'')
# Out:
# Minha professora uma vez disse 'Estudar e chave do sucesso.'
