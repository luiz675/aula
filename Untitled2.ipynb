# %% [markdown]
# <a href="https://colab.research.google.com/github/luiz675/aula/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
texto = '  Luiz Adriano de Lina  '

# %%
texto.upper()
# Out:
# '  LUIZ ADRIANO DE LINA  '

# %%
texto.lower()
# Out:
# '  luiz adriano de lina  '

# %%
texto.strip()
# Out:
# 'Luiz Adriano de Lina'

# %%
texto.replace('n','m')
# Out:
# '  Luiz Adriamo de Lima  '

# %%
texto = texto.strip().replace('n','m').upper()
texto
# Out:
# 'LUIZ ADRIAMO DE LIMA'

# %%
texto = '  Carolina Aparecida mely  '

# %%
texto.upper()
# Out:
# '  CAROLINA APARECIDA MELY  '

# %%
texto.lower()
# Out:
# '  carolina aparecida mely  '

# %%
texto.strip()
# Out:
# 'Carolina Aparecida mely'

# %%
texto.replace('y','o')
# Out:
# '  Carolina Aparecida melo  '

# %%
texto = texto.strip().replace('y','o').upper()
texto
# Out:
# 'CAROLINA APARECIDA MELO'
