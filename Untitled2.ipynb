# %% [markdown]
# <a href="https://colab.research.google.com/github/luiz675/aula/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = input('Escreva o seu nome: ')
# Out:
# Escreva o seu nome: luiz

# %%
nome
# Out:
# 'luiz'

# %%
ano_entrada = input('Escreva o ano de engresso do(a) estudante: ')
# Out:
# Escreva o ano de engresso do(a) estudante: 2023

# %%
type(ano_entrada)
# Out:
# str

# %%
ano_entrada = int(input('Escreva o ano de engresso do(a) estudante: '))
# Out:
# Escreva o ano de engresso do(a) estudante: 2023

# %%
type(ano_entrada)
# Out:
# int

# %%
nota_entrada = float(input('Digite a nota de teste de ingresso: '))
print(f'ano de entrada {ano_entrada} - nota do teste de ingresso{nota_entrada}')
# Out:
# Digite a nota de teste de ingresso: 2023
# ano de entrada 2023 - nota do teste de ingresso2023.0
