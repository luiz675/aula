# %% [markdown]
# <a href="https://colab.research.google.com/github/luiz675/aula/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = input('Digite o seu nome: ')
print(f'Ola, {nome}. ')
# Out:
# Digite o seu nome: Luiz
# Ola, Luiz.

# %%
nome = input('Digite o se nome: ')
idade = int(input('Didite a sua idade: '))
print(f'Olá {nome}, você tem {idade} anos. ')
# Out:
# Digite o se nome: Luiz
# Didite a sua idade: 43
# Olá Luiz, você tem 43 anos.

# %%
nome = input('Digite o seu nome: ')
idade = int(input('Digite a sua idade: '))
altura = float(input('Digite a sua altura: '))
print(f'Olá {nome}, você tem {idade} anos e mede {altura} metros. ')
# Out:
# Digite o seu nome: Luiz
# Digite a sua idade: 43
# Digite a sua altura: 1.62
# Olá Luiz, você tem 43 anos e mede 1.62 metros.

# %%
print('Olá mundo!')
# Out:
# Olá mundo!

# %%
print(10)
# Out:
# 10

# %%
print('Luiz', 43, 'anos')
# Out:
# Luiz 43 anos
